# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
# ----> 3 np.savez_compressed('projection_dataset.npz', X=X, y=y)
#       4 b = np.load('projection_dataset.npz')
#       5 b
#
# NameError: name 'X' is not defined

# %%
file=np.load("projection_dataset.npz")
file.files
# Out:
# ['X', 'y']

# %%
file["X"].shape, file["y"].shape
# Out:
# ((3000, 4096), (3000, 4096))

# %%
X_train=file["X"][:2400]
y_train=file["y"][:2400]

X_test=file["X"][2400:]
y_test=file["y"][2400:]

from training_util import train_model
from training_util import PersonaHobbyDataset
from vector_projection_model import HobbyProjector

import torch
from torch.utils.data import Dataset, DataLoader

dataset_train=PersonaHobbyDataset(X_train,y_train)
dataset_test=PersonaHobbyDataset(X_test,y_test)

train_loader = DataLoader(dataset_train, batch_size=16, shuffle=True)
val_loader = DataLoader(dataset_test, batch_size=16, shuffle=False)

model = HobbyProjector(input_dim=X.shape[1], output_dim=y.shape[1])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_model(model, train_loader, val_loader, num_epochs=5, device=str(device))
# Out:
# Starting training on cuda...
# Epoch 1/5 - Train Loss: 0.2730 - Val Loss: 0.1614
#   Example saved best model.
# Epoch 2/5 - Train Loss: 0.1609 - Val Loss: 0.1220
#   Example saved best model.
# Epoch 3/5 - Train Loss: 0.1232 - Val Loss: 0.1079
#   Example saved best model.
# Epoch 4/5 - Train Loss: 0.1004 - Val Loss: 0.0937
#   Example saved best model.
# Epoch 5/5 - Train Loss: 0.0827 - Val Loss: 0.0889
#   Example saved best model.
# Training complete.
# HobbyProjector(
#   (net): Sequential(
#     (0): Linear(in_features=4096, out_features=2048, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=2048, out_features=2048, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=2048, out_features=4096, bias=True)
#   )
# )
